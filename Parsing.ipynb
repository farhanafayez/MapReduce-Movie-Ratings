# %%
import numpy as np
import pandas as pd
import csv
import xlrd

df1 = pd.read_csv("beatles-diskography.csv")
df1
# Out:
#                                     Title           Released  \
# 0                        Please Please Me      22 March 1963
# 1                        With the Beatles   22 November 1963
# 2           Beatlemania! With the Beatles   25 November 1963
# 3              Introducing... The Beatles    10 January 1964
# 4                       Meet the Beatles!    20 January 1964
# 5                         Twist and Shout    3 February 1964
# 6               The Beatles' Second Album      10 April 1964
# 7            The Beatles' Long Tall Sally        11 May 1964
# 8                      A Hard Day's Night       26 June 1964
# 9                                     NaN       10 July 1964
# 10                          Something New       20 July 1964
# 11                       Beatles for Sale    4 December 1964
# 12                            Beatles '65   15 December 1964
# 13                             Beatles VI       14 June 1965
# ...

# %%
pd.read_table("beatles-diskography.csv")
# Out:
#    Title,Released,Label,UK Chart Position,US Chart Position,BPI Certification,RIAA Certification
# 0   Please Please Me,22 March 1963,Parlophone(UK),...
# 1   With the Beatles,22 November 1963,Parlophone(U...
# 2   Beatlemania! With the Beatles,25 November 1963...
# 3   Introducing... The Beatles,10 January 1964,Vee...
# 4   Meet the Beatles!,20 January 1964,Capitol(US),...
# 5   Twist and Shout,3 February 1964,Capitol(CAN),-...
# 6   The Beatles' Second Album,10 April 1964,Capito...
# 7   The Beatles' Long Tall Sally,11 May 1964,Capit...
# 8   A Hard Day's Night,26 June 1964,United Artists...
# 9              ,10 July 1964,Parlophone(UK),1,-,Gold,
# 10  Something New,20 July 1964,Capitol(US),-,2,,Pl...
# 11  Beatles for Sale,4 December 1964,Parlophone(UK...
# 12  Beatles '65,15 December 1964,Capitol(US),-,1,,...
# 13  Beatles VI,14 June 1965,"Parlophone(NZ), Capit...
# 14   Help!,6 August 1965,Parlophone(UK),1,-,Platinum,
# 15     ,13 August 1965,Capitol(US)[C],-,1,,3xPlatinum
# ...

# %%
xl = pd.ExcelFile("2013_ERCOT_Hourly_Load_Data.xls")
xl.sheet_names
[u'2013']
df = xl.parse("2013")
df.head()
# Out:
#              Hour_End        COAST         EAST     FAR_WEST       NORTH  \
# 0 2013-01-01 01:00:00  7606.263544  1073.892438  1411.750567  784.978166
# 1 2013-01-01 02:00:00  7388.082714  1035.021938  1403.472287  776.307387
# 2 2013-01-01 03:00:00  7178.867878  1036.088697  1395.053150  768.125748
# 3 2013-01-01 04:00:00  7038.822581  1032.648841  1395.508820  770.937969
# 4 2013-01-01 05:00:00  6990.857940  1042.823044  1401.216842  779.089313
#
#         NORTH_C     SOUTHERN      SOUTH_C        WEST         ERCOT
# 0  10369.094390  2206.675077  4368.490945  882.931901  28704.077028
# 1  10152.358518  2159.733208  4233.587967  872.404750  28020.968769
# 2   9988.051418  2065.114706  4082.862860  868.853938  27383.018395
# 3   9946.658655  1990.903699  4010.489608  865.701201  27051.671374
# 4  10096.664190  1954.807585  4038.655997  879.924249  27184.039160

# %%
df.groupby('Hour_End')['COAST'].agg([pd.np.min, pd.np.max, pd.np.mean])
# Out:
#                              amin          amax          mean
# Hour_End
# 2013-01-01 01:00:00   7606.263544   7606.263544   7606.263544
# 2013-01-01 02:00:00   7388.082714   7388.082714   7388.082714
# 2013-01-01 03:00:00   7178.867878   7178.867878   7178.867878
# 2013-01-01 04:00:00   7038.822581   7038.822581   7038.822581
# 2013-01-01 05:00:00   6990.857940   6990.857940   6990.857940
# 2013-01-01 06:00:00   7049.790189   7049.790189   7049.790189
# 2013-01-01 07:00:00   7176.995344   7176.995344   7176.995344
# 2013-01-01 08:00:00   7222.680062   7222.680062   7222.680062
# 2013-01-01 09:00:00   7313.827285   7313.827285   7313.827285
# 2013-01-01 10:00:00   7676.263088   7676.263088   7676.263088
# 2013-01-01 11:00:00   8060.585862   8060.585862   8060.585862
# 2013-01-01 12:00:00   8392.872943   8392.872943   8392.872943
# 2013-01-01 13:00:00   8508.460276   8508.460276   8508.460276
# 2013-01-01 14:00:00   8497.619547   8497.619547   8497.619547
# ...
